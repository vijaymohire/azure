# %% [markdown]
# # Deploy to an online endpoint
#
# To consume a model from an application, you can deploy the model to an online endpoint. You'll create an MLflow model from local files and test the endpoint.
#
# ## Before you start
#
# You'll need the latest version of the  **azure-ai-ml** package to run the code in this notebook. Run the cell below to verify that it is installed.
#
# > **Note**:
# > If the **azure-ai-ml** package is not installed, run `pip install azure-ai-ml` to install it.

# %%
pip show azure-ai-ml
# Out:
# Name: azure-ai-ml
# Version: 1.20.0
# Summary: Microsoft Azure Machine Learning Client Library for Python
# Home-page: https://github.com/Azure/azure-sdk-for-python
# Author: Microsoft Corporation
# Author-email: azuresdkengsysadmins@microsoft.com
# License: MIT License
# Location: /anaconda/envs/azureml_py38/lib/python3.9/site-packages
# Requires: azure-common, azure-core, azure-mgmt-core, azure-storage-blob, azure-storage-file-datalake, azure-storage-file-share, colorama, isodate, jsonschema, marshmallow, msrest, opencensus-ext-azure, opencensus-ext-logging, pydash, pyjwt, pyyaml, strictyaml, tqdm, typing-extensions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connect to your workspace
#
# With the required SDK packages installed, now you're ready to connect to your workspace.
#
# To connect to a workspace, we need identifier parameters - a subscription ID, resource group name, and workspace name. Since you're working with a compute instance, managed by Azure Machine Learning, you can use the default values to connect to the workspace.

# %%
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient

try:
    credential = DefaultAzureCredential()
    # Check if given credential can get token successfully.
    credential.get_token("https://management.azure.com/.default")
except Exception as ex:
    # Fall back to InteractiveBrowserCredential in case DefaultAzureCredential not work
    credential = InteractiveBrowserCredential()

# %%
# Get a handle to workspace
ml_client = MLClient.from_config(credential=credential)
# Out:
# Found the config file in: /config.json

# %% [markdown]
# ## Define and create an endpoint
#
# Ultimately, the goal is to deploy a model to an endpoint. Therefore, you first need to create an endpoint. The endpoint will be a HTTPS endpoint that an application can call to receive predictions from the model. An application can consume an endpoint by using its URI, and authenticating with a key or token.
#
# Run the following cell to define the endpoint. Note that the name of the endpoint has to be unique. You'll use the `datetime` function to generate a unique name.

# %%
from azure.ai.ml.entities import ManagedOnlineEndpoint
import datetime

online_endpoint_name = "endpoint-" + datetime.datetime.now().strftime("%m%d%H%M%f")

# create an online endpoint
endpoint = ManagedOnlineEndpoint(
    name=online_endpoint_name,
    description="Online endpoint for MLflow diabetes model",
    auth_mode="key",
)

# %% [markdown]
# Next, you'll create the endpoint by running the following cell. This may take several minutes. While your endpoint is being created, you can read about [what are Azure Machine Learning endpoints](https://learn.microsoft.com/azure/machine-learning/concept-endpoints).

# %%
ml_client.begin_create_or_update(endpoint).result()
# Out:
# ManagedOnlineEndpoint({'public_network_access': 'Enabled', 'provisioning_state': 'Succeeded', 'scoring_uri': 'https://endpoint-10051340913828.northeurope.inference.ml.azure.com/score', 'openapi_uri': 'https://endpoint-10051340913828.northeurope.inference.ml.azure.com/swagger.json', 'name': 'endpoint-10051340913828', 'description': 'Online endpoint for MLflow diabetes model', 'tags': {}, 'properties': {'createdBy': 'Vijayananda Mohire', 'createdAt': '2024-10-05T13:40:36.476987+0000', 'lastModifiedAt': '2024-10-05T13:40:36.476987+0000', 'azureml.onlineendpointid': '/subscriptions/3576052a-a13e-4f72-af77-4dc230441dc0/resourcegroups/rg-dp100-l4672009a662749d691/providers/microsoft.machinelearningservices/workspaces/mlw-dp100-l4672009a662749d691/onlineendpoints/endpoint-10051340913828', 'AzureAsyncOperationUri': 'https://management.azure.com/subscriptions/3576052a-a13e-4f72-af77-4dc230441dc0/providers/Microsoft.MachineLearningServices/locations/northeurope/mfeOperationsStatus/oeidp:31fe2db4-ec5b-41c7-b695-61410fe01b72:7c1035b3-2a0e-485e-89ba-44a27acfb673?api-version=2022-02-01-preview'}, 'print_as_yaml': False, 'id': '/subscriptions/3576052a-a13e-4f72-af77-4dc230441dc0/resourceGroups/rg-dp100-l4672009a662749d691/providers/Microsoft.MachineLearningServices/workspaces/mlw-dp100-l4672009a662749d691/onlineEndpoints/endpoint-10051340913828', 'Resource__source_path': '', 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/ci4672009a662749d691/code/Users/vijaymohire/azure-ml-labs/Labs/11', 'creation_context': None, 'serialize': <msrest.serialization.Serializer object at 0x7f6d401f2490>, 'auth_mode': 'key', 'location': 'northeurope', 'identity': <azure.ai.ml.entities._credentials.IdentityConfiguration object at 0x7f6d40a7d580>, 'traffic': {}, 'mirror_traffic': {}, 'kind': 'Managed'})

# %% [markdown]
# <p style="color:red;font-size:120%;background-color:yellow;font-weight:bold"> IMPORTANT! Wait until the endpoint is created successfully before continuing! A green notification should appear in the studio. </p>
#
# ## Configure the deployment
#
# You can deploy multiple models to an endpoint. This is mostly useful when you want to update the deployed model while keeping the current model in production. You'll need to configure the deployment to specify which model needs to be deployed to an endpoint. In the following cell, you'll refer to the model trained and stored in the local `model` folder (stored in the same folder as this notebook). Note that since you're working with an MLflow model, you don't need to specify the environment or scoring script.
#
# You'll also specify the infrastructure needed for the model to be deployed.

# %%
from azure.ai.ml.entities import Model, ManagedOnlineDeployment
from azure.ai.ml.constants import AssetTypes

# create a blue deployment
model = Model(
    path="./model",
    type=AssetTypes.MLFLOW_MODEL,
    description="my sample mlflow model",
)

blue_deployment = ManagedOnlineDeployment(
    name="blue",
    endpoint_name=online_endpoint_name,
    model=model,
    instance_type="Standard_D2a_v4",
    instance_count=1,
)

# %% [markdown]
# ## Create the deployment
#
# Finally, you can actually deploy the model to the endpoint by running the following cell:

# %%
ml_client.online_deployments.begin_create_or_update(blue_deployment).result()
# Out:
# Check: endpoint endpoint-10051340913828 exists
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ml_client.online_deployments.begin_create_or_update(blue_deployment).result()
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/core/tracing/decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_telemetry/activity.py:289, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     285     with tracer.span():
#     286         with log_activity(
#     287             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     288         ):
# --> 289             return f(*args, **kwargs)
#     290 elif hasattr(logger, "package_logger"):
#     291     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_deployment_operations.py:218, in OnlineDeploymentOperations.begin_create_or_update(self, deployment, local, vscode_debug, skip_script_validation, local_enable_gpu, **kwargs)
#     216     log_and_raise_error(ex)
#     217 else:
# --> 218     raise ex
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_deployment_operations.py:213, in OnlineDeploymentOperations.begin_create_or_update(self, deployment, local, vscode_debug, skip_script_validation, local_enable_gpu, **kwargs)
#     211         return poller
#     212     except Exception as ex:
# --> 213         raise ex
#     214 except Exception as ex:  # pylint: disable=W0718
#     215     if isinstance(ex, (ValidationException, SchemaValidationError)):
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_deployment_operations.py:196, in OnlineDeploymentOperations.begin_create_or_update(self, deployment, local, vscode_debug, skip_script_validation, local_enable_gpu, **kwargs)
#     192         module_logger.info("\nStarting deployment")
#     194     deployment_rest = deployment._to_rest_object(location=location)  # type: ignore
# --> 196     poller = self._online_deployment.begin_create_or_update(
#     197         resource_group_name=self._resource_group_name,
#     198         workspace_name=self._workspace_name,
#     199         endpoint_name=deployment.endpoint_name,
#     200         deployment_name=deployment.name,
#     201         body=deployment_rest,
#     202         polling=AzureMLPolling(
#     203             LROConfigurations.POLL_INTERVAL,
#     204             path_format_arguments=path_format_arguments,
#     205             **self._init_kwargs,
#     206         ),
#     207         polling_interval=LROConfigurations.POLL_INTERVAL,
#     208         **self._init_kwargs,
#     209         cls=lambda response, deserialized, headers: OnlineDeployment._from_rest_object(deserialized),
#     210     )
#     211     return poller
#     212 except Exception as ex:
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/core/tracing/decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_restclient/v2023_04_01_preview/operations/_online_deployments_operations.py:933, in OnlineDeploymentsOperations.begin_create_or_update(self, resource_group_name, workspace_name, endpoint_name, deployment_name, body, **kwargs)
#     931 cont_token = kwargs.pop('continuation_token', None)  # type: Optional[str]
#     932 if cont_token is None:
# --> 933     raw_result = self._create_or_update_initial(
#     934         resource_group_name=resource_group_name,
#     935         workspace_name=workspace_name,
#     936         endpoint_name=endpoint_name,
#     937         deployment_name=deployment_name,
#     938         body=body,
#     939         api_version=api_version,
#     940         content_type=content_type,
#     941         cls=lambda x,y,z: x,
#     942         **kwargs
#     943     )
#     944 kwargs.pop('error_map', None)
#     946 def get_long_running_output(pipeline_response):
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_restclient/v2023_04_01_preview/operations/_online_deployments_operations.py:864, in OnlineDeploymentsOperations._create_or_update_initial(self, resource_group_name, workspace_name, endpoint_name, deployment_name, body, **kwargs)
#     862 if response.status_code not in [200, 201]:
#     863     map_error(status_code=response.status_code, response=response, error_map=error_map)
# --> 864     raise HttpResponseError(response=response, error_format=ARMErrorFormat)
#     866 response_headers = {}
#     867 if response.status_code == 200:
#
# HttpResponseError: (BadRequest) The request is invalid.
# Code: BadRequest
# Message: The request is invalid.
# Exception Details:	(InferencingClientCallFailed) {"error":{"code":"Validation","message":"{\"errors\":{\"VmSize\":[\"Not enough quota available for Standard_D2a_v4 in SubscriptionId 3576052a-a13e-4f72-af77-4dc230441dc0. Current usage/limit: 0/0. Additional needed: 4 Please see troubleshooting guide, available here: https://aka.ms/oe-tsg#error-outofquota\"]},\"type\":\"https://tools.ietf.org/html/rfc9110#section-15.5.1\",\"title\":\"One or more validation errors occurred.\",\"status\":400,\"traceId\":\"00-572dd202e179b82e7686a46d9be86866-fd924d86edb1da9a-01\"}"}}
# 	Code: InferencingClientCallFailed
# 	Message: {"error":{"code":"Validation","message":"{\"errors\":{\"VmSize\":[\"Not enough quota available for Standard_D2a_v4 in SubscriptionId 3576052a-a13e-4f72-af77-4dc230441dc0. Current usage/limit: 0/0. Additional needed: 4 Please see troubleshooting guide, available here: https://aka.ms/oe-tsg#error-outofquota\"]},\"type\":\"https://tools.ietf.org/html/rfc9110#section-15.5.1\",\"title\":\"One or more validation errors occurred.\",\"status\":400,\"traceId\":\"00-572dd202e179b82e7686a46d9be86866-fd924d86edb1da9a-01\"}"}}
# Additional Information:Type: ComponentName
# Info: {
#     "value": "managementfrontend"
# }Type: Correlation
# Info: {
#     "value": {
#         "operation": "572dd202e179b82e7686a46d9be86866",
#         "request": "57b7e63a9549e98c"
#     }
# }Type: Environment
# Info: {
#     "value": "northeurope"
# }Type: Location
# Info: {
#     "value": "northeurope"
# }Type: Time
# Info: {
#     "value": "2024-10-05T13:44:33.7017168+00:00"
# }

# %% [markdown]
# The deployment of the model may take 10-15 minutes. While waiting for the model to be deployed, you can learn more about [managed endpoints in this video](https://www.youtube.com/watch?v=SxFGw_OBxNM&ab_channel=MicrosoftDeveloper).
#
# <p style="color:red;font-size:120%;background-color:yellow;font-weight:bold"> IMPORTANT! Wait until the deployment is completed before continuing! A green notification should appear in the studio.</p>
#
# Since you only have one model deployed to the endpoint, you want this deployment to take 100% of the traffic. If you deploy multiple models to the endpoint, you could use the same approach to distribute traffic across the deployed models.

# %%
# blue deployment takes 100 traffic
endpoint.traffic = {"blue": 100}
ml_client.begin_create_or_update(endpoint).result()
# Out:
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # blue deployment takes 100 traffic
#       2 endpoint.traffic = {"blue": 100}
# ----> 3 ml_client.begin_create_or_update(endpoint).result()
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_ml_client.py:1257, in MLClient.begin_create_or_update(self, entity, **kwargs)
#    1238 def begin_create_or_update(
#    1239     self,
#    1240     entity: R,
#    1241     **kwargs,
#    1242 ) -> LROPoller[R]:
#    1243     """Creates or updates an Azure ML resource asynchronously.
#    1244
#    1245     :param entity: The resource to create or update.
#    (...)
#    1254         , ~azure.ai.ml.entities.BatchEndpoint, ~azure.ai.ml.entities.Schedule]]
#    1255     """
# -> 1257     return _begin_create_or_update(entity, self._operation_container.all_operations, **kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_ml_client.py:1351, in _(entity, operations, *args, **kwargs)
#    1348 @_begin_create_or_update.register(OnlineEndpoint)
#    1349 def _(entity: OnlineEndpoint, operations, *args, **kwargs):
#    1350     module_logger.debug("Creating or updating online_endpoints")
# -> 1351     return operations[AzureMLResourceType.ONLINE_ENDPOINT].begin_create_or_update(entity, **kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/core/tracing/decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_telemetry/activity.py:289, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     285     with tracer.span():
#     286         with log_activity(
#     287             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     288         ):
# --> 289             return f(*args, **kwargs)
#     290 elif hasattr(logger, "package_logger"):
#     291     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_endpoint_operations.py:263, in OnlineEndpointOperations.begin_create_or_update(self, endpoint, local)
#     261     log_and_raise_error(ex)
#     262 else:
# --> 263     raise ex
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_endpoint_operations.py:258, in OnlineEndpointOperations.begin_create_or_update(self, endpoint, local)
#     255         return poller
#     257     except Exception as ex:
# --> 258         raise ex
#     259 except Exception as ex:  # pylint: disable=W0718
#     260     if isinstance(ex, (ValidationException, SchemaValidationError)):
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_endpoint_operations.py:247, in OnlineEndpointOperations.begin_create_or_update(self, endpoint, local)
#     242     if hasattr(endpoint_resource.properties, "compute"):
#     243         endpoint_resource.properties.compute = orchestrators.get_asset_arm_id(
#     244             endpoint_resource.properties.compute,
#     245             azureml_type=AzureMLResourceType.COMPUTE,
#     246         )
# --> 247     poller = self._online_operation.begin_create_or_update(
#     248         resource_group_name=self._resource_group_name,
#     249         workspace_name=self._workspace_name,
#     250         endpoint_name=endpoint.name,
#     251         body=endpoint_resource,
#     252         cls=lambda response, deserialized, headers: OnlineEndpoint._from_rest_object(deserialized),
#     253         **self._init_kwargs,
#     254     )
#     255     return poller
#     257 except Exception as ex:
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/core/tracing/decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_restclient/v2022_02_01_preview/operations/_online_endpoints_operations.py:921, in OnlineEndpointsOperations.begin_create_or_update(self, resource_group_name, workspace_name, endpoint_name, body, **kwargs)
#     919 cont_token = kwargs.pop('continuation_token', None)  # type: Optional[str]
#     920 if cont_token is None:
# --> 921     raw_result = self._create_or_update_initial(
#     922         resource_group_name=resource_group_name,
#     923         workspace_name=workspace_name,
#     924         endpoint_name=endpoint_name,
#     925         body=body,
#     926         content_type=content_type,
#     927         cls=lambda x,y,z: x,
#     928         **kwargs
#     929     )
#     930 kwargs.pop('error_map', None)
#     932 def get_long_running_output(pipeline_response):
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_restclient/v2022_02_01_preview/operations/_online_endpoints_operations.py:856, in OnlineEndpointsOperations._create_or_update_initial(self, resource_group_name, workspace_name, endpoint_name, body, **kwargs)
#     854 if response.status_code not in [200, 201]:
#     855     map_error(status_code=response.status_code, response=response, error_map=error_map)
# --> 856     raise HttpResponseError(response=response, error_format=ARMErrorFormat)
#     858 response_headers = {}
#     859 if response.status_code == 200:
#
# HttpResponseError: (BadRequest) The request is invalid.
# Code: BadRequest
# Message: The request is invalid.
# Exception Details:	(InferencingClientCallFailed) {"error":{"code":"Validation","message":"{\"errors\":{\"DeploymentWeights\":[\"Deployments given positive traffic values should be either in a successful or failed state. Unmatched deployments: [blue]\"]},\"type\":\"https://tools.ietf.org/html/rfc9110#section-15.5.1\",\"title\":\"One or more validation errors occurred.\",\"status\":400,\"traceId\":\"00-d2d1dcd5b558ca3e0f01824674f21552-4a65f5ac9f4812d8-01\"}"}}
# 	Code: InferencingClientCallFailed
# 	Message: {"error":{"code":"Validation","message":"{\"errors\":{\"DeploymentWeights\":[\"Deployments given positive traffic values should be either in a successful or failed state. Unmatched deployments: [blue]\"]},\"type\":\"https://tools.ietf.org/html/rfc9110#section-15.5.1\",\"title\":\"One or more validation errors occurred.\",\"status\":400,\"traceId\":\"00-d2d1dcd5b558ca3e0f01824674f21552-4a65f5ac9f4812d8-01\"}"}}
# Additional Information:Type: ComponentName
# Info: {
#     "value": "managementfrontend"
# }Type: Correlation
# Info: {
#     "value": {
#         "operation": "d2d1dcd5b558ca3e0f01824674f21552",
#         "request": "755202c9b8287b48"
#     }
# }Type: Environment
# Info: {
#     "value": "northeurope"
# }Type: Location
# Info: {
#     "value": "northeurope"
# }Type: Time
# Info: {
#     "value": "2024-10-05T13:45:50.9607657+00:00"
# }

# %% [markdown]
# <p style="color:red;font-size:120%;background-color:yellow;font-weight:bold"> IMPORTANT! Wait until the blue deployment is configured before continuing! A green notification should appear in the studio. </p>
#
# ## Test the deployment
#
# Let's test the deployed model by invoking the endpoint. A JSON file with sample data is used as input. The trained model predicts whether a patient has diabetes or not, based on medical data like age, BMI, and the number of pregnancies. A `[0]` indicates a patient doesn't have diabetes. A `[1]` means a patient does have diabetes.

# %%
# test the blue deployment with some sample data
response = ml_client.online_endpoints.invoke(
    endpoint_name=online_endpoint_name,
    deployment_name="blue",
    request_file="sample-data.json",
)

if response[1]=='1':
    print("Diabetic")
else:
    print ("Not diabetic")
# Out:
# ---------------------------------------------------------------------------
# ValidationException                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # test the blue deployment with some sample data
# ----> 2 response = ml_client.online_endpoints.invoke(
#       3     endpoint_name=online_endpoint_name,
#       4     deployment_name="blue",
#       5     request_file="sample-data.json",
#       6 )
#       8 if response[1]=='1':
#       9     print("Diabetic")
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/core/tracing/decorator.py:78, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#      76 span_impl_type = settings.tracing_implementation()
#      77 if span_impl_type is None:
# ---> 78     return func(*args, **kwargs)
#      80 # Merge span is parameter is set, but only if no explicit parent are passed
#      81 if merge_span and not passed_in_parent:
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/_telemetry/activity.py:289, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     285     with tracer.span():
#     286         with log_activity(
#     287             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     288         ):
# --> 289             return f(*args, **kwargs)
#     290 elif hasattr(logger, "package_logger"):
#     291     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_endpoint_operations.py:340, in OnlineEndpointOperations.invoke(self, endpoint_name, request_file, deployment_name, input_data, params_override, local, **kwargs)
#     338 # Until this bug is resolved https://msdata.visualstudio.com/Vienna/_workitems/edit/1446538
#     339 if deployment_name:
# --> 340     self._validate_deployment_name(endpoint_name, deployment_name)
#     342 with open(request_file, "rb") as f:  # type: ignore[arg-type]
#     343     data = json.loads(f.read())
#
# File /anaconda/envs/azureml_py38/lib/python3.9/site-packages/azure/ai/ml/operations/_online_endpoint_operations.py:458, in OnlineEndpointOperations._validate_deployment_name(self, endpoint_name, deployment_name)
#     456 if deployments_list:
#     457     if deployment_name not in deployments_list:
# --> 458         raise ValidationException(
#     459             message=f"Deployment name {deployment_name} not found for this endpoint",
#     460             target=ErrorTarget.ONLINE_ENDPOINT,
#     461             no_personal_data_message="Deployment name not found for this endpoint",
#     462             error_category=ErrorCategory.USER_ERROR,
#     463             error_type=ValidationErrorType.RESOURCE_NOT_FOUND,
#     464         )
#     465 else:
#     466     msg = "No deployment exists for this endpoint"
#
# ValidationException: Deployment name blue not found for this endpoint

# %% [markdown]
# Optionally, you can change the values in the `sample-data.json` file to try and get a different prediction.

# %% [markdown]
# ## List endpoints
#
# Although you can view all endpoints in the Studio, you can also list all endpoints using the SDK:

# %%
endpoints = ml_client.online_endpoints.list()
for endp in endpoints:
    print(endp.name)
# Out:
# endpoint-10051340913828

# %% [markdown]
# ## Get endpoint details
#
# If you want more information about a specific endpoint, you can explore the details using the SDK too.

# %%
# Get the details for online endpoint
endpoint = ml_client.online_endpoints.get(name=online_endpoint_name)

# existing traffic details
print(endpoint.traffic)

# Get the scoring URI
print(endpoint.scoring_uri)
# Out:
# {}
# https://endpoint-10051340913828.northeurope.inference.ml.azure.com/score

# %% [markdown]
# ## Delete the endpoint and deployment
#
# As an endpoint is always available, it can't be paused to save costs. To avoid unnecessary costs, delete the endpoint.

# %%
ml_client.online_endpoints.begin_delete(name=online_endpoint_name)
# Out:
# ....
